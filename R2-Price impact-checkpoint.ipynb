# %% [markdown]
# Now we check hypothesis of log dependency of price impact and try to estimate regression parameters. Remind that we need coefficient of regression
# $$
# \overline{\Delta p} = K \log V
# $$
#
# Alternative hypothesis is power law:
# $$
# \overline{\Delta p } = K V^{\beta}
# $$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.formula.api import gls
import os, sys
import json

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
files = [fname for fname in os.listdir('./data')]
files
# Out:
# ['RMM2.feather',
#  'SiM2.feather',
#  'GDM2.feather',
#  'RIM2.feather',
#  'BRM2.feather',
#  'VBM2.feather',
#  'NGM2.feather',
#  'CRM2.feather',
#  'EuM2.feather',
#  'SRM2.feather',
#  'GZM2.feather',
#  'EDM2.feather']

# %%
df = pd.read_feather('./data/CRM2.feather')
df.head()
# Out:
#                      Time             MOMENT DIRECTION  PRICE_min  PRICE_max  \
# 0 2022-05-04 10:01:30.870  20220504100130870         S      10.60      10.84
# 1 2022-05-04 10:01:31.140  20220504100131140         B      10.95      11.71
# 2 2022-05-04 10:01:31.247  20220504100131247         S      11.25      11.25
# 3 2022-05-04 10:01:31.250  20220504100131250         S      10.39      11.21
# 4 2022-05-04 10:01:31.260  20220504100131260         S      10.39      10.39
#
#    VOLUME_sum  DELTA_OI_sum        Date         TimeOnly  DOW   H  Impact  \
# 0          50         -62.0  2022-05-04  10:01:30.870000    3  10    0.24
# 1           5           0.0  2022-05-04  10:01:31.140000    3  10    0.76
# 2           6         -12.0  2022-05-04  10:01:31.247000    3  10    0.00
# 3          40           0.0  2022-05-04  10:01:31.250000    3  10    0.82
# 4           4           0.0  2022-05-04  10:01:31.260000    3  10    0.00
#
#      BID    ASK  BID_SIZE  ASK_SIZE        MID  Spread
# 0  10.60  11.70      23.0       1.0  11.150000    1.10
# 1  10.60  11.71      23.0      16.0  11.155001    1.11
# 2  11.21  11.71       1.0      16.0  11.460000    0.50
# 3  10.39  11.71       4.0      16.0  11.050000    1.32
# 4  10.38  11.71    1320.0      16.0  11.045000    1.33

# %%
# Import pice steps
with open('pricesteps.json', 'r') as f:
    pricesteps = json.load(f)
pricesteps
# Out:
# {'RI': 10,
#  'RM': 0.5,
#  'SR': 1,
#  'GZ': 1,
#  'VB': 1,
#  'Si': 1,
#  'Eu': 1,
#  'ED': 0.0001,
#  'CR': 0.01,
#  'BR': 0.01,
#  'GD': 0.1,
#  'NG': 0.001}

# %%
def prepare4reg(ticker, pricestep=1, binwidth=1):
    df = pd.read_feather(f'./data/{ticker}.feather')
    
    max_impact = np.percentile(df['Impact'][df['Impact'] > 0], 99.9)
    
    if binwidth == 1:        
        df_grouped = df[['VOLUME_sum', 'Impact']] \
            [(df['Impact'] > 0) & (df['Impact'] < max_impact)] \
            .groupby(by=['VOLUME_sum'], as_index=True, sort=True) \
            .mean()
    else:
        bins = np.arange(df['VOLUME_sum'].min(), df['VOLUME_sum'].max()+1, binwidth)
        df['VolBin'] = pd.cut(df['VOLUME_sum'], bins=bins)    
        df_grouped = df[['VolBin', 'Impact']] \
            [(df['Impact'] > 0) & (df['Impact'] < max_impact)] \
            .groupby(by=['VolBin'], as_index=True, sort=True) \
            .mean()
        df_grouped.index = df_grouped.index.map(lambda ab: (ab.left + ab.right)/2)
    
    return df_grouped.index.to_numpy(), \
           df_grouped['Impact'].values / pricestep

# %% [markdown]
# ### Regression

# %%
df_results = pd.DataFrame(columns=['R2', 'F-stat p-value',
                                   'K', 'K p-value', 
                                   'Intercept', 'Intercept p-value'])

def add2results(model_id, res, df):
    df.loc[model_id, 'R2'] = res.rsquared_adj
    df.loc[model_id, 'F-stat p-value'] = res.f_pvalue
        
    df.loc[model_id, 'Intercept'] = res.params[0]
    df.loc[model_id, 'Intercept p-value'] = res.pvalues[0]
    df.loc[model_id, 'K'] = res.params[1]
    df.loc[model_id, 'K p-value'] = res.pvalues[1]

# %%
def fit_model(ticker, pricestep, 
              reg_range=[None, None], plot_range=None, 
              binwidth=1, model='lin', verbose=True):
    
    X, Y = prepare4reg(ticker, pricestep, binwidth)
    if plot_range is None:
        plot_range = [X.min(), X.max()]
    if reg_range is None:
        reg_range = plot_range
    
    x = X[(X >= reg_range[0]) & (X <= reg_range[1])]
    y = Y[(X >= reg_range[0]) & (X <= reg_range[1])]
    dxy = pd.DataFrame({'x': x, 'y': y})
    
    if model == 'lin':
        model = gls('y ~ x', dxy)
        res = model.fit()
        linreg = lambda x: res.params[0] + res.params[1] * x
    
    elif model == 'log':
        dxy.x += 1  # min volume == zero impact
        model = gls('y ~ np.log(x)', dxy)
        res = model.fit()
        linreg = lambda x: res.params[0] + res.params[1] * np.log(x)

    elif model == 'pow':
        dxy.x, dxy.y = np.log(x), np.log(y)
        model = gls('y ~ x', dxy)
        res = model.fit()
        linreg = lambda x: np.exp(res.params[0]) * x**res.params[1] 
    
    else:
        raise ValueError('Unknown model')
    
    if verbose:
        plt.title(f'{ticker}, {model} model')
        sns.scatterplot(X[(X >= plot_range[0]) & (X <= plot_range[1])], 
                        Y[(X >= plot_range[0]) & (X <= plot_range[1])])
        
        xr = np.linspace(reg_range[0], reg_range[1], 100)
        sns.lineplot(xr, linreg(xr), color='r')
         
    return res, x, y

# %% [markdown]
# ## RIM2

# %%
ticker = 'RIM2'
reg_range = [1, 20]
plot_range = [1, 150]
model = 'lin'

model_id = ticker + ' : ' + model + ' : ' + str(reg_range) 

res, x, y = fit_model(ticker, 0.5, reg_range, plot_range, binwidth=3, model=model)
add2results(model_id, res, df_results)
print(df_results.loc[model_id])
# Out:
# R2                    0.991006
# F-stat p-value        0.000019
# K                     3.109024
# K p-value             0.000019
# Intercept            18.347836
# Intercept p-value     0.000248
# Name: RIM2 : lin : [1, 20], dtype: object

# %%
reg_range = [20, 150]
model = 'log'

model_id = ticker + ' : ' + model + ' : ' + str(reg_range) 

res, x, y = fit_model(ticker, 0.5, reg_range, plot_range, binwidth=3, model=model)
add2results(model_id, res, df_results)
print(df_results.loc[model_id])
# Out:
# R2                     0.684041
# F-stat p-value              0.0
# K                     88.485081
# K p-value                   0.0
# Intercept           -202.292196
# Intercept p-value      0.000012
# Name: RIM2 : log : [20, 150], dtype: object

# %%
reg_range = [20, 150]
model = 'pow'

model_id = ticker + ' : ' + model + ' : ' + str(reg_range) 

res, x, y = fit_model(ticker, 0.5, reg_range, plot_range, binwidth=3, model=model)
add2results(model_id, res, df_results)
print(df_results.loc[model_id])
# Out:
# R2                    0.76675
# F-stat p-value            0.0
# K                    0.555457
# K p-value                 0.0
# Intercept            2.749225
# Intercept p-value         0.0
# Name: RIM2 : pow : [20, 150], dtype: object

# %% [markdown]
# ## RMM2

# %%
ticker = 'RMM2'
reg_range = [1, 20]
plot_range = [1, 100]
model = 'lin'

model_id = ticker + ' : ' + model + ' : ' + str(reg_range) 

res, x, y = fit_model(ticker, 0.5, reg_range, plot_range, binwidth=3, model=model)
add2results(model_id, res, df_results)
print(df_results.loc[model_id])
# Out:
# R2                   0.953194
# F-stat p-value       0.000532
# K                    0.028387
# K p-value            0.000532
# Intercept            1.107185
# Intercept p-value    0.000004
# Name: RMM2 : lin : [1, 20], dtype: object

# %%
reg_range = [20, 100]
model = 'log'

model_id = ticker + ' : ' + model + ' : ' + str(reg_range) 

res, x, y = fit_model(ticker, 0.5, reg_range, plot_range, binwidth=3, model=model)
add2results(model_id, res, df_results)
print(df_results.loc[model_id])
# Out:
# R2                   0.523793
# F-stat p-value       0.000012
# K                    1.236775
# K p-value            0.000012
# Intercept           -2.263968
# Intercept p-value    0.020888
# Name: RMM2 : log : [20, 100], dtype: object

# %%
reg_range = [20, 100]
model = 'pow'

model_id = ticker + ' : ' + model + ' : ' + str(reg_range) 

res, x, y = fit_model(ticker, 0.5, reg_range, plot_range, binwidth=3, model=model)
add2results(model_id, res, df_results)
print(df_results.loc[model_id])
# Out:
# R2                   0.623937
# F-stat p-value       0.000001
# K                    0.467361
# K p-value            0.000001
# Intercept           -0.908068
# Intercept p-value    0.003617
# Name: RMM2 : pow : [20, 100], dtype: object

# %% [markdown]
# ## SiM2

# %%
ticker = 'SiM2'
reg_range = [1, 50]
plot_range = [1, 600]
model = 'lin'

model_id = ticker + ' : ' + model + ' : ' + str(reg_range) 

res, x, y = fit_model(ticker, 0.5, reg_range, plot_range, binwidth=5, model=model)
add2results(model_id, res, df_results)
print(df_results.loc[model_id])
# Out:
# R2                   0.983339
# F-stat p-value            0.0
# K                    0.263876
# K p-value                 0.0
# Intercept            4.513097
# Intercept p-value    0.000001
# Name: SiM2 : lin : [1, 50], dtype: object

# %%
ticker = 'SiM2'
reg_range = [40, 600]
plot_range = [1, 600]
model = 'log'

model_id = ticker + ' : ' + model + ' : ' + str(reg_range) 

res, x, y = fit_model(ticker, 0.5, reg_range, plot_range, binwidth=5, model=model)
add2results(model_id, res, df_results)
print(df_results.loc[model_id])
# Out:
# R2                   0.821804
# F-stat p-value            0.0
# K                    14.93888
# K p-value                 0.0
# Intercept           -42.61462
# Intercept p-value         0.0
# Name: SiM2 : log : [40, 600], dtype: object

# %%
ticker = 'SiM2'
reg_range = [40, 600]
plot_range = [1, 600]
model = 'pow'

model_id = ticker + ' : ' + model + ' : ' + str(reg_range) 

res, x, y = fit_model(ticker, 0.5, reg_range, plot_range, binwidth=5, model=model)
add2results(model_id, res, df_results)
print(df_results.loc[model_id])
# Out:
# R2                   0.874627
# F-stat p-value            0.0
# K                    0.428624
# K p-value                 0.0
# Intercept            1.275375
# Intercept p-value         0.0
# Name: SiM2 : pow : [40, 600], dtype: object
