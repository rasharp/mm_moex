# %% [markdown]
# We used method of plotting linear regression of complement cumulative distribution function (see for example [[Maslow, Mills 2001]](#References)):
# $$ CCDF(V) \propto V^{-\alpha} $$
#
# In log-log scale it is simply linear regression:
# $$ \log CCDF(V) = -\alpha \log V + c $$

# %%
import numpy as np
import pandas as pd
from statsmodels.formula.api import gls
import seaborn as sns
import matplotlib.pyplot as plt
import os, sys

# %%
files = [fname for fname in os.listdir('data')]
files
# Out:
# ['RMM2.feather',
#  'SiM2.feather',
#  'GDM2.feather',
#  'RIM2.feather',
#  'BRM2.feather',
#  'VBM2.feather',
#  'NGM2.feather',
#  'CRM2.feather',
#  'EuM2.feather',
#  'SRM2.feather',
#  'GZM2.feather',
#  'EDM2.feather']

# %%
df = pd.read_feather('./data/CRM2.feather')
df.head()
# Out:
#                      Time             MOMENT DIRECTION  PRICE_min  PRICE_max  \
# 0 2022-05-04 10:01:30.870  20220504100130870         S      10.60      10.84
# 1 2022-05-04 10:01:31.140  20220504100131140         B      10.95      11.71
# 2 2022-05-04 10:01:31.247  20220504100131247         S      11.25      11.25
# 3 2022-05-04 10:01:31.250  20220504100131250         S      10.39      11.21
# 4 2022-05-04 10:01:31.260  20220504100131260         S      10.39      10.39
#
#    VOLUME_sum  DELTA_OI_sum        Date         TimeOnly  DOW   H  Impact  \
# 0          50         -62.0  2022-05-04  10:01:30.870000    3  10    0.24
# 1           5           0.0  2022-05-04  10:01:31.140000    3  10    0.76
# 2           6         -12.0  2022-05-04  10:01:31.247000    3  10    0.00
# 3          40           0.0  2022-05-04  10:01:31.250000    3  10    0.82
# 4           4           0.0  2022-05-04  10:01:31.260000    3  10    0.00
#
#      BID    ASK  BID_SIZE  ASK_SIZE        MID  Spread
# 0  10.60  11.70      23.0       1.0  11.150000    1.10
# 1  10.60  11.71      23.0      16.0  11.155001    1.11
# 2  11.21  11.71       1.0      16.0  11.460000    0.50
# 3  10.39  11.71       4.0      16.0  11.050000    1.32
# 4  10.38  11.71    1320.0      16.0  11.045000    1.33

# %% [markdown]
# ### Histogram (PDF) plots

# %%
common_filters = 'DOW <= 5 and H <= 17 and VOLUME_sum > 1 and VOLUME_sum < 100'
common_filters
# Out:
# 'DOW <= 5 and H <= 17 and VOLUME_sum > 1 and VOLUME_sum < 100'

# %%
fig, axises = plt.subplots(4, 3, figsize=(20, 20), sharex=True)
i_subplot = 0

for file_name in files:
    df = pd.read_feather(f'./data/{file_name}').query(common_filters)
    sns.histplot(data=df, x='VOLUME_sum', ax=axises.flat[i_subplot], binwidth=5)
    axises.flat[i_subplot].title.set_text(file_name[:file_name.find('.feather')])
    i_subplot += 1

# %% [markdown]
# ### CCDF plots

# %%
fig, axises = plt.subplots(4, 3, figsize=(20, 20), sharex=True)
i_subplot = 0

i_subplot = 0
for file_name in files:
    df = pd.read_feather(f'./data/{file_name}')
    XY = df[['VOLUME_sum', 'DOW']].groupby(by=['VOLUME_sum'], as_index=True, sort=True)\
        .count()['DOW']
    ccdf = 1. - np.cumsum(XY / np.sum(XY))
    X, Y = XY[1:-1].index, ccdf[1:-1]
    
    sns.scatterplot(x=np.log(X), y=np.log(Y), ax=axises.flat[i_subplot])
    axises.flat[i_subplot].title.set_text(file_name[:file_name.find('.feather')])
    i_subplot += 1

# %% [markdown]
# ### Regressions

# %%
df_results = pd.DataFrame(columns=['R2', 'F-stat p-value', 'Alpha', 'Alpha p-value', 'start', 'end'])

def add2results(ticker, res, df):
    df.loc[ticker, 'R2'] = res.rsquared_adj
    df.loc[ticker, 'F-stat p-value'] = res.f_pvalue
    df.loc[ticker, 'Alpha'] = res.params[1]
    df.loc[ticker, 'Alpha p-value'] = res.pvalues[1]

# %%
def linreg(ticker, start=None, end=None, verbose=True, logx=True, logy=True):
    df = pd.read_feather(f'./data/{ticker}.feather')
    XY = df[['VOLUME_sum', 'DOW']].groupby(by=['VOLUME_sum'], as_index=True, sort=True)\
        .count()['DOW']
    ccdf = 1. - np.cumsum(XY / np.sum(XY))
    
    X, Y = XY[1:-1].index, ccdf[1:-1]
    start = start if start else X[1]
    end = end if end else X[-1]    
    x = np.log(X) if logx else X
    y = np.log(Y) if logy else Y
    
    dxy = pd.DataFrame({'X': x[(X>=start) & (X<=end)], 
                        'Y': y[(X>=start) & (X<=end)]})
    model = gls('Y ~ X', data=dxy)
    res = model.fit() 
    
    if verbose:
        print(f'Origin range from {X[0]} till {X[-1]}')
        print(f'Regression range from {start} till {end}')

        sns.scatterplot(x, y)
        linregfunc = lambda x: res.params[0] + res.params[1]*x  # linear regression function
        xr = np.log([start, end]) if logx else np.array([start, end])
        sns.lineplot(xr, linregfunc(xr), color='r')
        
    return res

# %%
files
# Out:
# ['RMM2.feather',
#  'SiM2.feather',
#  'GDM2.feather',
#  'RIM2.feather',
#  'BRM2.feather',
#  'VBM2.feather',
#  'NGM2.feather',
#  'CRM2.feather',
#  'EuM2.feather',
#  'SRM2.feather',
#  'GZM2.feather',
#  'EDM2.feather']

# %%
ticker = 'RIM2'
start, end = 10, None

res = linreg(ticker, start=start, end=end)
add2results(ticker, res, df_results)
df_results.loc[ticker, 'start'], df_results.loc[ticker, 'end'] = start, end
print(df_results.loc[ticker])
# Out:
# Origin range from 2 till 494
# Regression range from 10 till 494
# R2                0.993727
# F-stat p-value         0.0
# Alpha            -2.634632
# Alpha p-value          0.0
# start                   10
# end                   None
# Name: RIM2, dtype: object
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ticker = 'RMM2'
start, end = 10, 300

res = linreg(ticker, start=start, end=end)
add2results(ticker, res, df_results)
df_results.loc[ticker, 'start'], df_results.loc[ticker, 'end'] = start, end
print(df_results.loc[ticker])
# Out:
# Origin range from 2 till 493
# Regression range from 10 till 300
# R2                 0.98743
# F-stat p-value         0.0
# Alpha            -2.143425
# Alpha p-value          0.0
# start                   10
# end                    300
# Name: RMM2, dtype: object
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ticker = 'SRM2'
start, end = 20, 2000

res = linreg(ticker, start=start, end=end)
add2results(ticker, res, df_results)
df_results.loc[ticker, 'start'], df_results.loc[ticker, 'end'] = start, end
print(df_results.loc[ticker])
# Out:
# Origin range from 2 till 2245
# Regression range from 20 till 2000
# R2                0.962971
# F-stat p-value         0.0
# Alpha            -2.199359
# Alpha p-value          0.0
# start                   20
# end                   2000
# Name: SRM2, dtype: object
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ticker = 'GZM2'
start, end = 10, 500

res = linreg(ticker, start=start, end=end)
add2results(ticker, res, df_results)
df_results.loc[ticker, 'start'], df_results.loc[ticker, 'end'] = start, end
print(df_results.loc[ticker])
# Out:
# Origin range from 2 till 774
# Regression range from 10 till 500
# R2                0.970116
# F-stat p-value         0.0
# Alpha            -2.091458
# Alpha p-value          0.0
# start                   10
# end                    500
# Name: GZM2, dtype: object
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ticker = 'SiM2'
start, end = 10, 4000

res = linreg(ticker, start=start, end=end)
add2results(ticker, res, df_results)
df_results.loc[ticker, 'start'], df_results.loc[ticker, 'end'] = start, end
print(df_results.loc[ticker])
# Out:
# Origin range from 2 till 6673
# Regression range from 10 till 4000
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# R2                0.964433
# F-stat p-value         0.0
# Alpha            -2.242341
# Alpha p-value          0.0
# start                   10
# end                   4000
# Name: SiM2, dtype: object

# %%
"Additional for low Si"
ticker = 'SiM2'
start, end = 10, 200

res = linreg(ticker, start=start, end=end)
add2results(ticker+' 10-200', res, df_results)
df_results.loc[ticker+' 10-200', 'start'], df_results.loc[ticker+' 10-200', 'end'] = start, end
print(df_results.loc[ticker+' 10-200'])
# Out:
# Origin range from 2 till 6673
# Regression range from 10 till 200
# R2                0.983794
# F-stat p-value         0.0
# Alpha            -1.401207
# Alpha p-value          0.0
# start                   10
# end                    200
# Name: SiM2 10-200, dtype: object
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ticker = 'EuM2'
start, end = 10, 400

res = linreg(ticker, start=start, end=end)
add2results(ticker, res, df_results)
df_results.loc[ticker, 'start'], df_results.loc[ticker, 'end'] = start, end
print(df_results.loc[ticker])
# Out:
# Origin range from 2 till 592
# Regression range from 10 till 400
# R2                0.988056
# F-stat p-value         0.0
# Alpha            -2.109258
# Alpha p-value          0.0
# start                   10
# end                    400
# Name: EuM2, dtype: object
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ticker = 'EDM2'
start, end = 10, 500

res = linreg(ticker, start=start, end=end)
add2results(ticker, res, df_results)
df_results.loc[ticker, 'start'], df_results.loc[ticker, 'end'] = start, end
print(df_results.loc[ticker])
# Out:
# Origin range from 2 till 2000
# Regression range from 10 till 500
# R2                0.983154
# F-stat p-value         0.0
# Alpha            -1.587894
# Alpha p-value          0.0
# start                   10
# end                    500
# Name: EDM2, dtype: object
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ticker = 'CRM2'
start, end = 10, 100

res = linreg(ticker, start=start, end=end)
add2results(ticker, res, df_results)
df_results.loc[ticker, 'start'], df_results.loc[ticker, 'end'] = start, end
print(df_results.loc[ticker])
# Out:
# Origin range from 2 till 143
# Regression range from 10 till 100
# R2                0.981738
# F-stat p-value         0.0
# Alpha            -2.087169
# Alpha p-value          0.0
# start                   10
# end                    100
# Name: CRM2, dtype: object
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ticker = 'BRM2'
start, end = 20, 500

res = linreg(ticker, start=start, end=end)
add2results(ticker, res, df_results)
df_results.loc[ticker, 'start'], df_results.loc[ticker, 'end'] = start, end
print(df_results.loc[ticker])
# Out:
# Origin range from 2 till 691
# Regression range from 20 till 500
# R2                0.981741
# F-stat p-value         0.0
# Alpha            -2.467087
# Alpha p-value          0.0
# start                   20
# end                    500
# Name: BRM2, dtype: object
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ticker = 'GDM2'
start, end = 10, 500

res = linreg(ticker, start=start, end=end)
add2results(ticker, res, df_results)
df_results.loc[ticker, 'start'], df_results.loc[ticker, 'end'] = start, end
print(df_results.loc[ticker])
# Out:
# Origin range from 2 till 623
# Regression range from 10 till 500
# R2                0.973935
# F-stat p-value         0.0
# Alpha            -2.013095
# Alpha p-value          0.0
# start                   10
# end                    500
# Name: GDM2, dtype: object
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ticker = 'NGM2'
start, end = 10, 500

res = linreg(ticker, start=start, end=end)
add2results(ticker, res, df_results)
df_results.loc[ticker, 'start'], df_results.loc[ticker, 'end'] = start, end
print(df_results.loc[ticker])
# Out:
# Origin range from 2 till 534
# Regression range from 10 till 500
# R2                0.993123
# F-stat p-value         0.0
# Alpha            -1.902405
# Alpha p-value          0.0
# start                   10
# end                    500
# Name: NGM2, dtype: object
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ubuntu/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Results

# %%
df_results
# Out:
#                    R2 F-stat p-value     Alpha Alpha p-value start   end
# RIM2         0.993727            0.0 -2.634632           0.0    10  None
# RMM2          0.98743            0.0 -2.143425           0.0    10   300
# SRM2         0.962971            0.0 -2.199359           0.0    20  2000
# GZM2         0.970116            0.0 -2.091458           0.0    10   500
# SiM2         0.964433            0.0 -2.242341           0.0    10  4000
# SiM2 10-200  0.983794            0.0 -1.401207           0.0    10   200
# EuM2         0.988056            0.0 -2.109258           0.0    10   400
# EDM2         0.983154            0.0 -1.587894           0.0    10   500
# CRM2         0.981738            0.0 -2.087169           0.0    10   100
# BRM2         0.981741            0.0 -2.467087           0.0    20   500
# GDM2         0.973935            0.0 -2.013095           0.0    10   500
# NGM2         0.993123            0.0 -1.902405           0.0    10   500

# %%
df_results.to_csv('alphas_results')
